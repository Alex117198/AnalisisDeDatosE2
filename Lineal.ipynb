# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd

# %%
#definir data con la ruta del archivo
data =  pd.read_csv("C:/Users/ALYE1/OneDrive/Documents/La U mi perro/S9/Análisis de Datos/T2/lineal/data.csv", sep=",")

# %%
#mostrar datos
data
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
#definir variables
x = data[["metro"]]
y = data["precio"]

# %%
#mostrar la grafica
data.plot.scatter(x="metro", y="precio")
# Out:
# <Axes: xlabel='metro', ylabel='precio'>

# %%
#crear el modelo de regreción lineal
lrModel = linear_model.LinearRegression()
lrModel.fit(x, y)
# Out:
# LinearRegression()

# %%
#realizar prediccion en x
prediction = lrModel.predict(x)

# %%
#imprimir intersección y pendiente
print("Intersección (b): ", lrModel.intercept_)
print("Pendiente (m): ", lrModel.coef_)
# Out:
# Intersección (b):  361.25714285714287
# Pendiente (m):  [5.64571429]

# %%
#mostrar resultados
plt.scatter(x, y, label= "Datos reales")
plt.plot(x, prediction, color="red", label="Regresión Lineal")
plt.xlabel("Metros")
plt.ylabel("Precio")
plt.legend()
plt.show()
